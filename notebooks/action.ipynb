# %%
import os
import sys
import numpy as np
from __future__ import annotations

from typing import Dict, List, Sequence, Union

import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)
 
from syn_project.utils_train import *
from syn_project.utils_color_analysis import *
from syn_project.utils_notebook import *

# %matplotlib widget

# %%
CONDITIONS = ["action_tr16", "action_tr32", "action_tr64", "action_tr128"]
START_VISION = [True]
KEY_DIMS = ["v_latents", "attr", "color", "v_attr_color", "v_color_attr"]
checkpoint_epoch = 0
# --- Tableau de métriques ---
metrics_df = compute_metrics_table(
        conditions=CONDITIONS,
        start_vision=START_VISION,
        cat_names=CAT_NAMES,
        n_samples_test=1000,
        split="test",
        checkpoint_epoch=checkpoint_epoch,
    )
display_metrics_table(metrics_df)  # en Jupyter : afficher directement la sortie

    # --- Poids d'attention ---
weights = compute_attention_weights(CONDITIONS, KEY_DIMS, checkpoint_epoch)

plot_attention_weights(
    weights,
    key_dims=KEY_DIMS,
    x_labels={
        "v_latents": "Gvision",
        "attr": "Gspatial",
        "color": "Gcouleur",
        "v_attr_color": "Gcouleur2",
        "v_color_attr": "Gspatial2",
    },
    subplot_titles={
        "action_tr16": "16",
        "action_tr32": "32",
        "action_tr64": "64",
        "action_tr128": "128",
    },
    colors={
        "v_latents": "#1D9E75",
        "attr": "#534AB7",
        "color": "#534AB7",
        "v_attr_color": "#E15759",
        "v_color_attr": "#E15759",
    },
    suptitle="Poids d'attention par condition",
)
# Out:
# /home/lucas/gwsyn/syn_project/utils_notebook.py:673: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location="cpu")
# ...

# %%
metrics_df
# Out:
#               start_v      ssim  lda_score  accuracy  weight_v_latents  \
# condition
# action_tr16      True  0.872334      0.998     0.997      7.309617e-08
# action_tr32      True  0.875001      0.998     0.999      4.510788e-02
# action_tr64      True  0.880750      0.687     0.999      4.093721e-02
# action_tr128     True  0.891171      0.643     0.997      9.999948e-01
#
#                weight_attr  weight_color  weight_v_attr_color  \
# condition
# action_tr16   2.554873e-06  6.846211e-06             0.999987
# action_tr32   1.485860e-04  7.536579e-06             0.954702
# action_tr64   7.186212e-01  1.162506e-07             0.240441
# action_tr128  1.308132e-07  2.144960e-08             0.000004
#
#               weight_v_color_attr
# condition
# action_tr16          3.880887e-06
# action_tr32          3.434367e-05
# action_tr64          1.546287e-07
# action_tr128         9.324290e-07

# %%
pub_df = build_publication_table(
    metrics_df,
    n_neurons={"action_tr16": 16, "action_tr32": 32, "action_tr64": 64, "action_tr128": 128},   # nouvelle colonne
    start_v=True,                                        # filtre si plusieurs lignes/condition
    include_columns=["n_neurons", "accuracy", "ssim", "lda_score"],  # tu choisis
    rename_map={"accuracy": "Accuracy", "ssim": "SSIM", "lda_score": "LDA score", "n_neurons": "Hidden layer size"},
    decimals=3,
)

# %%
pub_df
# Out:
#    Hidden layer size  Accuracy   SSIM  LDA score
# 0                 16     0.997  0.872      0.998
# 1                 32     0.999  0.875      0.998
# 2                 64     0.999  0.881      0.687
# 3                128     0.997  0.891      0.643

# %%
render_publication_table(pub_df, decimals=3)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 560x300 with 1 Axes>, <Axes: >)
