# %%
import os
import sys

root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)
 
from syn_project.utils_train import *
from syn_project.utils_color_analysis import *
from syn_project.utils_notebook import *
# %matplotlib widget

# %%
with total_silence(): 
    CONDITIONS = [
    "alpha01",
    "alpha02",
    "alpha03",
    "alpha04",
    "alpha05",
    "alpha06",
    "alpha07",
    "alpha08",
    "alpha09",
    "alpha10",
    "alpha11",
    "alpha12",
    "alpha13",
    "alpha14",
    "alpha15",
    "alpha16",
    "alpha17",
    "alpha18",
    "alpha19",
    "alpha20",

    ]

    metrics_df = compute_metrics_table(
        conditions=CONDITIONS,
        start_vision=[False],
        cat_names=CAT_NAMES,
        n_samples_test=300,
        split="test",
        checkpoint_epoch=0,
        compute_accuracy=False
    )

# %%
metrics_df
# Out:
#            start_v      ssim  lda_score  accuracy
# condition
# alpha01      False  0.955060      0.930       NaN
# alpha02      False  0.954225      0.949       NaN
# alpha03      False  0.952313      0.966       NaN
# alpha04      False  0.954944      0.992       NaN
# alpha05      False  0.955706      0.959       NaN
# alpha06      False  0.952344      0.870       NaN
# alpha07      False  0.956273      0.893       NaN
# alpha08      False  0.954512      0.627       NaN
# alpha09      False  0.955021      0.473       NaN
# alpha10      False  0.952409      0.635       NaN
# alpha11      False  0.954866      0.450       NaN
# alpha12      False  0.952682      0.478       NaN
# alpha13      False  0.950157      0.464       NaN
# alpha14      False  0.952960      0.455       NaN
# alpha15      False  0.951773      0.420       NaN
# alpha16      False  0.943556      0.390       NaN

# %%
plot_lda(metrics_df)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
